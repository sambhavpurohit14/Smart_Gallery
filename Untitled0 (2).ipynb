# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision.models import resnet50
from transformers import BertModel, BertTokenizer
from torchvision import transforms
from PIL import Image
import random
import json
import numpy as np

# %%
class TextEncoder(nn.Module):
    def __init__(self, out_dim):
        super().__init__()
        self.model = BertModel.from_pretrained('bert-base-uncased')

        #freezing all the layers
        for param in self.model.parameters():
            param.requires_grad = False

        # #unfreezing the last two encoder layers of bert (we need to experiment with this)
        # for layer in self.model.encoder.layer[-2:]:  # Last two layers
        #     for param in layer.parameters():
        #         param.requires_grad = True

        self.projection = nn.Sequential(
            nn.Linear(768, out_dim),
            nn.LayerNorm(out_dim)
        )

    def forward(self,input_ids,attention_mask):
        outputs = self.model(input_ids=input_ids, attention_mask=attention_mask)
        hidden_states = outputs.last_hidden_state  # Shape: (batch_size, seq_length, 768)

        # Create a mask to ignore padding tokens (0s in attention_mask)
        mask = attention_mask.unsqueeze(-1).expand_as(hidden_states)  # Shape: (batch_size, seq_length, 768)

        summed_hidden_states = hidden_states * mask  # Mask out padding tokens
        token_counts = mask.sum(dim=1, keepdim=True)  # Count the non-padding tokens
        avg_pooling = summed_hidden_states.sum(dim=1) / token_counts  # Average across the sequence

        # Apply the projection layer (linear + layernorm)
        return self.projection(avg_pooling)  # Shape: (batch_size, out_dim)

# %%
#this cell prints all the layers of bert (we have freezed everything except the projection layer)
from transformers import BertModel



# Load the BERT model
model = BertModel.from_pretrained('bert-base-uncased')

# Print all layers with their names
for name, param in model.named_parameters():
    print(f"Layer: {name} | Trainable: {param.requires_grad}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Layer: embeddings.word_embeddings.weight | Trainable: True
# Layer: embeddings.position_embeddings.weight | Trainable: True
# Layer: embeddings.token_type_embeddings.weight | Trainable: True
# Layer: embeddings.LayerNorm.weight | Trainable: True
# Layer: embeddings.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.0.attention.self.query.weight | Trainable: True
# Layer: encoder.layer.0.attention.self.query.bias | Trainable: True
# Layer: encoder.layer.0.attention.self.key.weight | Trainable: True
# Layer: encoder.layer.0.attention.self.key.bias | Trainable: True
# Layer: encoder.layer.0.attention.self.value.weight | Trainable: True
# Layer: encoder.layer.0.attention.self.value.bias | Trainable: True
# Layer: encoder.layer.0.attention.output.dense.weight | Trainable: True
# Layer: encoder.layer.0.attention.output.dense.bias | Trainable: True
# Layer: encoder.layer.0.attention.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.0.attention.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.0.intermediate.dense.weight | Trainable: True
# Layer: encoder.layer.0.intermediate.dense.bias | Trainable: True
# Layer: encoder.layer.0.output.dense.weight | Trainable: True
# Layer: encoder.layer.0.output.dense.bias | Trainable: True
# Layer: encoder.layer.0.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.0.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.1.attention.self.query.weight | Trainable: True
# Layer: encoder.layer.1.attention.self.query.bias | Trainable: True
# Layer: encoder.layer.1.attention.self.key.weight | Trainable: True
# Layer: encoder.layer.1.attention.self.key.bias | Trainable: True
# Layer: encoder.layer.1.attention.self.value.weight | Trainable: True
# Layer: encoder.layer.1.attention.self.value.bias | Trainable: True
# Layer: encoder.layer.1.attention.output.dense.weight | Trainable: True
# Layer: encoder.layer.1.attention.output.dense.bias | Trainable: True
# Layer: encoder.layer.1.attention.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.1.attention.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.1.intermediate.dense.weight | Trainable: True
# Layer: encoder.layer.1.intermediate.dense.bias | Trainable: True
# Layer: encoder.layer.1.output.dense.weight | Trainable: True
# Layer: encoder.layer.1.output.dense.bias | Trainable: True
# Layer: encoder.layer.1.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.1.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.2.attention.self.query.weight | Trainable: True
# Layer: encoder.layer.2.attention.self.query.bias | Trainable: True
# Layer: encoder.layer.2.attention.self.key.weight | Trainable: True
# Layer: encoder.layer.2.attention.self.key.bias | Trainable: True
# Layer: encoder.layer.2.attention.self.value.weight | Trainable: True
# Layer: encoder.layer.2.attention.self.value.bias | Trainable: True
# Layer: encoder.layer.2.attention.output.dense.weight | Trainable: True
# Layer: encoder.layer.2.attention.output.dense.bias | Trainable: True
# Layer: encoder.layer.2.attention.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.2.attention.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.2.intermediate.dense.weight | Trainable: True
# Layer: encoder.layer.2.intermediate.dense.bias | Trainable: True
# Layer: encoder.layer.2.output.dense.weight | Trainable: True
# Layer: encoder.layer.2.output.dense.bias | Trainable: True
# Layer: encoder.layer.2.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.2.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.3.attention.self.query.weight | Trainable: True
# Layer: encoder.layer.3.attention.self.query.bias | Trainable: True
# Layer: encoder.layer.3.attention.self.key.weight | Trainable: True
# Layer: encoder.layer.3.attention.self.key.bias | Trainable: True
# Layer: encoder.layer.3.attention.self.value.weight | Trainable: True
# Layer: encoder.layer.3.attention.self.value.bias | Trainable: True
# Layer: encoder.layer.3.attention.output.dense.weight | Trainable: True
# Layer: encoder.layer.3.attention.output.dense.bias | Trainable: True
# Layer: encoder.layer.3.attention.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.3.attention.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.3.intermediate.dense.weight | Trainable: True
# Layer: encoder.layer.3.intermediate.dense.bias | Trainable: True
# Layer: encoder.layer.3.output.dense.weight | Trainable: True
# Layer: encoder.layer.3.output.dense.bias | Trainable: True
# Layer: encoder.layer.3.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.3.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.4.attention.self.query.weight | Trainable: True
# Layer: encoder.layer.4.attention.self.query.bias | Trainable: True
# Layer: encoder.layer.4.attention.self.key.weight | Trainable: True
# Layer: encoder.layer.4.attention.self.key.bias | Trainable: True
# Layer: encoder.layer.4.attention.self.value.weight | Trainable: True
# Layer: encoder.layer.4.attention.self.value.bias | Trainable: True
# Layer: encoder.layer.4.attention.output.dense.weight | Trainable: True
# Layer: encoder.layer.4.attention.output.dense.bias | Trainable: True
# Layer: encoder.layer.4.attention.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.4.attention.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.4.intermediate.dense.weight | Trainable: True
# Layer: encoder.layer.4.intermediate.dense.bias | Trainable: True
# Layer: encoder.layer.4.output.dense.weight | Trainable: True
# Layer: encoder.layer.4.output.dense.bias | Trainable: True
# Layer: encoder.layer.4.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.4.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.5.attention.self.query.weight | Trainable: True
# Layer: encoder.layer.5.attention.self.query.bias | Trainable: True
# Layer: encoder.layer.5.attention.self.key.weight | Trainable: True
# Layer: encoder.layer.5.attention.self.key.bias | Trainable: True
# Layer: encoder.layer.5.attention.self.value.weight | Trainable: True
# Layer: encoder.layer.5.attention.self.value.bias | Trainable: True
# Layer: encoder.layer.5.attention.output.dense.weight | Trainable: True
# Layer: encoder.layer.5.attention.output.dense.bias | Trainable: True
# Layer: encoder.layer.5.attention.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.5.attention.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.5.intermediate.dense.weight | Trainable: True
# Layer: encoder.layer.5.intermediate.dense.bias | Trainable: True
# Layer: encoder.layer.5.output.dense.weight | Trainable: True
# Layer: encoder.layer.5.output.dense.bias | Trainable: True
# Layer: encoder.layer.5.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.5.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.6.attention.self.query.weight | Trainable: True
# Layer: encoder.layer.6.attention.self.query.bias | Trainable: True
# Layer: encoder.layer.6.attention.self.key.weight | Trainable: True
# Layer: encoder.layer.6.attention.self.key.bias | Trainable: True
# Layer: encoder.layer.6.attention.self.value.weight | Trainable: True
# Layer: encoder.layer.6.attention.self.value.bias | Trainable: True
# Layer: encoder.layer.6.attention.output.dense.weight | Trainable: True
# Layer: encoder.layer.6.attention.output.dense.bias | Trainable: True
# Layer: encoder.layer.6.attention.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.6.attention.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.6.intermediate.dense.weight | Trainable: True
# Layer: encoder.layer.6.intermediate.dense.bias | Trainable: True
# Layer: encoder.layer.6.output.dense.weight | Trainable: True
# Layer: encoder.layer.6.output.dense.bias | Trainable: True
# Layer: encoder.layer.6.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.6.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.7.attention.self.query.weight | Trainable: True
# Layer: encoder.layer.7.attention.self.query.bias | Trainable: True
# Layer: encoder.layer.7.attention.self.key.weight | Trainable: True
# Layer: encoder.layer.7.attention.self.key.bias | Trainable: True
# Layer: encoder.layer.7.attention.self.value.weight | Trainable: True
# Layer: encoder.layer.7.attention.self.value.bias | Trainable: True
# Layer: encoder.layer.7.attention.output.dense.weight | Trainable: True
# Layer: encoder.layer.7.attention.output.dense.bias | Trainable: True
# Layer: encoder.layer.7.attention.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.7.attention.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.7.intermediate.dense.weight | Trainable: True
# Layer: encoder.layer.7.intermediate.dense.bias | Trainable: True
# Layer: encoder.layer.7.output.dense.weight | Trainable: True
# Layer: encoder.layer.7.output.dense.bias | Trainable: True
# Layer: encoder.layer.7.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.7.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.8.attention.self.query.weight | Trainable: True
# Layer: encoder.layer.8.attention.self.query.bias | Trainable: True
# Layer: encoder.layer.8.attention.self.key.weight | Trainable: True
# Layer: encoder.layer.8.attention.self.key.bias | Trainable: True
# Layer: encoder.layer.8.attention.self.value.weight | Trainable: True
# Layer: encoder.layer.8.attention.self.value.bias | Trainable: True
# Layer: encoder.layer.8.attention.output.dense.weight | Trainable: True
# Layer: encoder.layer.8.attention.output.dense.bias | Trainable: True
# Layer: encoder.layer.8.attention.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.8.attention.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.8.intermediate.dense.weight | Trainable: True
# Layer: encoder.layer.8.intermediate.dense.bias | Trainable: True
# Layer: encoder.layer.8.output.dense.weight | Trainable: True
# Layer: encoder.layer.8.output.dense.bias | Trainable: True
# Layer: encoder.layer.8.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.8.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.9.attention.self.query.weight | Trainable: True
# Layer: encoder.layer.9.attention.self.query.bias | Trainable: True
# Layer: encoder.layer.9.attention.self.key.weight | Trainable: True
# Layer: encoder.layer.9.attention.self.key.bias | Trainable: True
# Layer: encoder.layer.9.attention.self.value.weight | Trainable: True
# Layer: encoder.layer.9.attention.self.value.bias | Trainable: True
# Layer: encoder.layer.9.attention.output.dense.weight | Trainable: True
# Layer: encoder.layer.9.attention.output.dense.bias | Trainable: True
# Layer: encoder.layer.9.attention.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.9.attention.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.9.intermediate.dense.weight | Trainable: True
# Layer: encoder.layer.9.intermediate.dense.bias | Trainable: True
# Layer: encoder.layer.9.output.dense.weight | Trainable: True
# Layer: encoder.layer.9.output.dense.bias | Trainable: True
# Layer: encoder.layer.9.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.9.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.10.attention.self.query.weight | Trainable: True
# Layer: encoder.layer.10.attention.self.query.bias | Trainable: True
# Layer: encoder.layer.10.attention.self.key.weight | Trainable: True
# Layer: encoder.layer.10.attention.self.key.bias | Trainable: True
# Layer: encoder.layer.10.attention.self.value.weight | Trainable: True
# Layer: encoder.layer.10.attention.self.value.bias | Trainable: True
# Layer: encoder.layer.10.attention.output.dense.weight | Trainable: True
# Layer: encoder.layer.10.attention.output.dense.bias | Trainable: True
# Layer: encoder.layer.10.attention.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.10.attention.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.10.intermediate.dense.weight | Trainable: True
# Layer: encoder.layer.10.intermediate.dense.bias | Trainable: True
# Layer: encoder.layer.10.output.dense.weight | Trainable: True
# Layer: encoder.layer.10.output.dense.bias | Trainable: True
# Layer: encoder.layer.10.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.10.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.11.attention.self.query.weight | Trainable: True
# Layer: encoder.layer.11.attention.self.query.bias | Trainable: True
# Layer: encoder.layer.11.attention.self.key.weight | Trainable: True
# Layer: encoder.layer.11.attention.self.key.bias | Trainable: True
# Layer: encoder.layer.11.attention.self.value.weight | Trainable: True
# Layer: encoder.layer.11.attention.self.value.bias | Trainable: True
# Layer: encoder.layer.11.attention.output.dense.weight | Trainable: True
# Layer: encoder.layer.11.attention.output.dense.bias | Trainable: True
# Layer: encoder.layer.11.attention.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.11.attention.output.LayerNorm.bias | Trainable: True
# Layer: encoder.layer.11.intermediate.dense.weight | Trainable: True
# Layer: encoder.layer.11.intermediate.dense.bias | Trainable: True
# Layer: encoder.layer.11.output.dense.weight | Trainable: True
# Layer: encoder.layer.11.output.dense.bias | Trainable: True
# Layer: encoder.layer.11.output.LayerNorm.weight | Trainable: True
# Layer: encoder.layer.11.output.LayerNorm.bias | Trainable: True
# Layer: pooler.dense.weight | Trainable: True
# Layer: pooler.dense.bias | Trainable: True
